# %%
After 0 steps:
pos=<x=-1, y=  0, z= 2>, vel=<x= 0, y= 0, z= 0>
pos=<x= 2, y=-10, z=-7>, vel=<x= 0, y= 0, z= 0>
pos=<x= 4, y= -8, z= 8>, vel=<x= 0, y= 0, z= 0>
pos=<x= 3, y=  5, z=-1>, vel=<x= 0, y= 0, z= 0>

After 1 step:
pos=<x= 2, y=-1, z= 1>, vel=<x= 3, y=-1, z=-1>
pos=<x= 3, y=-7, z=-4>, vel=<x= 1, y= 3, z= 3>
pos=<x= 1, y=-7, z= 5>, vel=<x=-3, y= 1, z=-3>
pos=<x= 2, y= 2, z= 0>, vel=<x=-1, y=-3, z= 1>

After 2 steps:
pos=<x= 5, y=-3, z=-1>, vel=<x= 3, y=-2, z=-2>
pos=<x= 1, y=-2, z= 2>, vel=<x=-2, y= 5, z= 6>
pos=<x= 1, y=-4, z=-1>, vel=<x= 0, y= 3, z=-6>
pos=<x= 1, y=-4, z= 2>, vel=<x=-1, y=-6, z= 2>

After 3 steps:
pos=<x= 5, y=-6, z=-1>, vel=<x= 0, y=-3, z= 0>
pos=<x= 0, y= 0, z= 6>, vel=<x=-1, y= 2, z= 4>
pos=<x= 2, y= 1, z=-5>, vel=<x= 1, y= 5, z=-4>
pos=<x= 1, y=-8, z= 2>, vel=<x= 0, y=-4, z= 0>

After 4 steps:
pos=<x= 2, y=-8, z= 0>, vel=<x=-3, y=-2, z= 1>
pos=<x= 2, y= 1, z= 7>, vel=<x= 2, y= 1, z= 1>
pos=<x= 2, y= 3, z=-6>, vel=<x= 0, y= 2, z=-1>
pos=<x= 2, y=-9, z= 1>, vel=<x= 1, y=-1, z=-1>

After 5 steps:
pos=<x=-1, y=-9, z= 2>, vel=<x=-3, y=-1, z= 2>
pos=<x= 4, y= 1, z= 5>, vel=<x= 2, y= 0, z=-2>
pos=<x= 2, y= 2, z=-4>, vel=<x= 0, y=-1, z= 2>
pos=<x= 3, y=-7, z=-1>, vel=<x= 1, y= 2, z=-2>

After 6 steps:
pos=<x=-1, y=-7, z= 3>, vel=<x= 0, y= 2, z= 1>
pos=<x= 3, y= 0, z= 0>, vel=<x=-1, y=-1, z=-5>
pos=<x= 3, y=-2, z= 1>, vel=<x= 1, y=-4, z= 5>
pos=<x= 3, y=-4, z=-2>, vel=<x= 0, y= 3, z=-1>

After 7 steps:
pos=<x= 2, y=-2, z= 1>, vel=<x= 3, y= 5, z=-2>
pos=<x= 1, y=-4, z=-4>, vel=<x=-2, y=-4, z=-4>
pos=<x= 3, y=-7, z= 5>, vel=<x= 0, y=-5, z= 4>
pos=<x= 2, y= 0, z= 0>, vel=<x=-1, y= 4, z= 2>

After 8 steps:
pos=<x= 5, y= 2, z=-2>, vel=<x= 3, y= 4, z=-3>
pos=<x= 2, y=-7, z=-5>, vel=<x= 1, y=-3, z=-1>
pos=<x= 0, y=-9, z= 6>, vel=<x=-3, y=-2, z= 1>
pos=<x= 1, y= 1, z= 3>, vel=<x=-1, y= 1, z= 3>

After 9 steps:
pos=<x= 5, y= 3, z=-4>, vel=<x= 0, y= 1, z=-2>
pos=<x= 2, y=-9, z=-3>, vel=<x= 0, y=-2, z= 2>
pos=<x= 0, y=-8, z= 4>, vel=<x= 0, y= 1, z=-2>
pos=<x= 1, y= 1, z= 5>, vel=<x= 0, y= 0, z= 2>

After 10 steps:
pos=<x= 2, y= 1, z=-3>, vel=<x=-3, y=-2, z= 1>
pos=<x= 1, y=-8, z= 0>, vel=<x=-1, y= 1, z= 3>
pos=<x= 3, y=-6, z= 1>, vel=<x= 3, y= 2, z=-3>
pos=<x= 2, y= 0, z= 4>, vel=<x= 1, y=-1, z=-1>

# %%
f = open('input-12.txt','r')
points = f.readlines()
f.close()

# %%
points
# Out:
# ['<x=4, y=12, z=13>\n',
#  '<x=-9, y=14, z=-3>\n',
#  '<x=-7, y=-1, z=2>\n',
#  '<x=-11, y=17, z=-1>\n']

# %%
moons = ['Io', 'Europa', 'Ganymede', 'Callisto']

# %%
pos_vel = {0:[4,12,13,0,0,0],1:[-9,14,-3,0,0,0],2:[-7,-1,2,0,0,0],3:[-11,17,-1,0,0,0]}

# %% [markdown]
# To apply gravity, consider every pair of moons. On each axis (x, y, and z), the velocity of each moon changes by exactly +1 or -1 to pull the moons together. For example, if Ganymede has an x position of 3, and Callisto has a x position of 5, then Ganymede's x velocity changes by +1 (because 5 > 3) and Callisto's x velocity changes by -1 (because 3 < 5). However, if the positions on a given axis are the same, the velocity on that axis does not change for that pair of moons.
#
# Once all gravity has been applied, apply velocity: simply add the velocity of each moon to its own position. For example, if Europa has a position of x=1, y=2, z=3 and a velocity of x=-2, y=0,z=3, then its new position would be x=-1, y=2, z=6. This process does not modify the velocity of any moon.

# %%
#gravity for each moon, how many are bigger or small than you. So where in the index of a sorted list, unless your value is the same. 

for moon in pos_vel.keys():
    pos_vel[moon][0:3]

# %%
from collections import Counter ,OrderedDict
import copy

# test case:
#pos_vel = OrderedDict({0:[-1,0,2,0,0,0],1:[2,-10,-7,0,0,0],2:[4,-8,8,0,0,0],3:[3,5,-1,0,0,0]})
#print(pos_vel)

#real one:
pos_vel = {0:[4,12,13,0,0,0],1:[-9,14,-3,0,0,0],2:[-7,-1,2,0,0,0],3:[-11,17,-1,0,0,0]}
og_pos = {0:[4,12,13],1:[-9,14,-3],2:[-7,-1,2],3:[-11,17,-1]}

def ranker(inpos,key = 0):
    dim_rank =Counter()
    for moon in pos_vel.keys():
        if moon != key:
            moonpos = pos_vel[moon]
            for index, dim in enumerate(['x','y','z']):
                if moonpos[index] > inpos[index]:
                    dim_rank[dim] +=1
                elif moonpos[index] < inpos[index]:
                    dim_rank[dim] -=1
                    
    #for index, dim in enumerate(['x','y','z']):
    #    if dim_rank[dim] >1:
    #        dim_rank[dim] =1
    #    elif dim_rank[dim] <0:
#            dim_rank[dim] =-1
        
    return dim_rank

def apply_gravity(velocities):
    for moon,vel in enumerate(velocities):
        pos_vel[moon][3] += vel['x']
        pos_vel[moon][4] += vel['y']
        pos_vel[moon][5] += vel['z']
        
        pos_vel[moon][0] += pos_vel[moon][3]
        pos_vel[moon][1] += pos_vel[moon][4]
        pos_vel[moon][2] += pos_vel[moon][5]
    return pos_vel

def total_energy():
    tot_energy = 0
    for moon in pos_vel.keys():
        pot_energy = 0
        kin_energy = 0
        
        x = abs(pos_vel[moon][0])
        y = abs(pos_vel[moon][1])
        z = abs(pos_vel[moon][2])
        pot_energy=x+y+z
        
        x = abs(pos_vel[moon][3])
        y = abs(pos_vel[moon][4])
        z = abs(pos_vel[moon][5])
        kin_energy=x+y+z

        tot_energy += kin_energy * pot_energy

    return tot_energy

def check():
    for moon in pos_vel.keys():
        for i in range(0,3):
            if pos_vel[moon][i] != og_pos[moon][i]:
                return False
    return True

store = []
#for j in range(0,100000):
#    store.append([pos_vel[0][0],pos_vel[0][1],pos_vel[0][2],pos_vel[1][0],pos_vel[1][1],pos_vel[1][2],\
#                  pos_vel[2][0],pos_vel[2][1],pos_vel[2][2],pos_vel[3][0],pos_vel[3][1],pos_vel[3][2],])

x_pos_vel=set()
y_pos_vel=set()
z_pos_vel=set()

while True:
    #print(j,'steps')
    delta_velocity = []
    for i in pos_vel.keys():
        delta_velocity.append(ranker(inpos = pos_vel[i][0:3],key=i))
    current = apply_gravity(delta_velocity)
    tenergy= total_energy()
    
    # part 2 crap:
    
    #print(current,tenergy)
    #brute force won't work!
    if check():
        print(j)
        print(pos_vel)
        break
    
    xes = (pos_vel[0][0],pos_vel[0][3],pos_vel[1][0],pos_vel[1][3],pos_vel[2][0],pos_vel[2][3],pos_vel[3][0],pos_vel[3][3])
    yes = (pos_vel[0][1],pos_vel[0][4],pos_vel[1][1],pos_vel[1][4],pos_vel[2][1],pos_vel[2][4],pos_vel[3][1],pos_vel[3][4])
    zes = (pos_vel[0][2],pos_vel[0][5],pos_vel[1][2],pos_vel[1][5],pos_vel[2][2],pos_vel[2][5],pos_vel[3][2],pos_vel[3][5])

    if xes in x_pos_vel and yes in y_pos_vel and zes in z_pos_vel:
        break
    x_pos_vel.add(xes)
    y_pos_vel.add(yes)
    z_pos_vel.add(zes)

    j+=1

    #print(tenergy)

# %%
from math import gcd

def getLCM(a, b):
    return a * b // gcd(a, b)

getLCM(len(x_pos_vel), getLCM(len(y_pos_vel), len(z_pos_vel)))
# Out:
# 467034091553512

# %%
#bullocks below

# %%
import pandas as pd

# %%
dat = pd.DataFrame(store)
#store

# %%
diff = dat-dat.loc[0]

# %%
box = []
for col in diff.columns:
    #diff[col]
    box.append(pd.Series(diff[diff[col]==0].index).diff())

# %%
pd.DataFrame(box).T
# Out:
#          0       1      2      3       4      5       6       7      8   \
# 0       NaN     NaN    NaN    NaN     NaN    NaN     NaN     NaN    NaN
# 1      11.0     3.0   55.0   13.0    23.0    9.0     7.0  1235.0    4.0
# 2       9.0     6.0    3.0   47.0    41.0    1.0    31.0    39.0   16.0
# 3      24.0     5.0   61.0   79.0    25.0   25.0    75.0    42.0   63.0
# 4      83.0    75.0   13.0  109.0    12.0    1.0   139.0   175.0   54.0
# 5      24.0   147.0   76.0   59.0    54.0  105.0     7.0   146.0    4.0
# 6     204.0    81.0   23.0   42.0   134.0    3.0    55.0  1475.0   44.0
# 7     318.0    68.0   80.0   28.0    12.0    9.0     5.0  2191.0    4.0
# 8      17.0   102.0   15.0    6.0    13.0   24.0   103.0   130.0   15.0
# 9       3.0    37.0   58.0   17.0   102.0   68.0    56.0    48.0    4.0
# 10     73.0    68.0   55.0   10.0    72.0   62.0     1.0   896.0   37.0
# 11     52.0   136.0   16.0   22.0    12.0   67.0    12.0  1001.0   14.0
# ...

# %%
dat.diff().plot()

# %%
og_pos
# Out:
# {0: [4, 12, 13], 1: [-9, 14, -3], 2: [-7, -1, 2], 3: [-11, 17, -1]}

# %%
After 4 steps:
pos=<x= 2, y=-8, z= 0>, vel=<x=-3, y=-2, z= 1>
pos=<x= 2, y= 1, z= 7>, vel=<x= 2, y= 1, z= 1>
pos=<x= 2, y= 3, z=-6>, vel=<x= 0, y= 2, z=-1>
pos=<x= 2, y=-9, z= 1>, vel=<x= 1, y=-1, z=-1>

# %%
delta_velocity
# Out:
# [Counter({'x': 3, 'y': -1, 'z': -1}),
#  Counter({'x': 1, 'y': 3, 'z': 3}),
#  Counter({'x': -3, 'y': 1, 'z': -3}),
#  Counter({'x': -1, 'y': -3, 'z': 1})]

# %%
After 0 steps:
pos=<x=-1, y=  0, z= 2>, vel=<x= 0, y= 0, z= 0>
pos=<x= 2, y=-10, z=-7>, vel=<x= 0, y= 0, z= 0>
pos=<x= 4, y= -8, z= 8>, vel=<x= 0, y= 0, z= 0>
pos=<x= 3, y=  5, z=-1>, vel=<x= 0, y= 0, z= 0>


After 1 step:
pos=<x= 2, y=-1, z= 1>, vel=<x= 3, y=-1, z=-1>
pos=<x= 3, y=-7, z=-4>, vel=<x= 1, y= 3, z= 3>
pos=<x= 1, y=-7, z= 5>, vel=<x=-3, y= 1, z=-3>
pos=<x= 2, y= 2, z= 0>, vel=<x=-1, y=-3, z= 1>

# %%
delta_velocity
# Out:
# [Counter({'x': 1, 'y': -1, 'z': -1}),
#  Counter({'x': -1, 'y': 1, 'z': 1}),
#  Counter({'x': 1, 'y': 1, 'z': -1}),
#  Counter({'x': -1, 'y': -1, 'z': 1})]
